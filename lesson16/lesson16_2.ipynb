# %%
import pandas as pd

df1 = pd.read_csv('new各鄉鎮市區人口密度.csv')
display(df1)
def format1(value:int):
    return f"第{value}號"
df1.style\
.format(precision=2, thousands=',', decimal='.')\
.format_index(format1)

# %%
df1 = pd.read_csv('new各鄉鎮市區人口密度.csv')
display(df1)

df1.style\
.format(precision=2, thousands=',', decimal='.')\
.format_index(lambda value:f"第{value}號")

# %%
import numpy as np
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                        index=pd.date_range(start="2021-01-01", periods=10),
                        columns=["Tokyo", "Taipei"])

# %%
weather_df.style\
.set_caption('Weather Conditions')\
.format_index(lambda v:v.strftime("%a"))\
.background_gradient(vmin=1,vmax=5,cmap='GnBu')
# Out:
# <style type="text/css">
# #T_f0f59_row0_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_f0f59_row0_col1, #T_f0f59_row2_col1, #T_f0f59_row7_col0 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_f0f59_row1_col0 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_f0f59_row1_col1 {
#   background-color: #a2dbb7;
#   color: #000000;
# }
# #T_f0f59_row2_col0 {
#   background-color: #08589b;
#   color: #f1f1f1;
# }
# #T_f0f59_row3_col0 {
#   background-color: #5bbacf;
#   color: #000000;
# }
# #T_f0f59_row3_col1 {
#   background-color: #84cfc1;
#   color: #000000;
# }
# #T_f0f59_row4_col0 {
#   background-color: #2f90c0;
#   color: #f1f1f1;
# }
# #T_f0f59_row4_col1 {
#   background-color: #3192c1;
#   color: #f1f1f1;
# }
# #T_f0f59_row5_col0 {
#   background-color: #acdfb7;
#   color: #000000;
# }
# #T_f0f59_row5_col1 {
#   background-color: #2c8ebf;
#   color: #f1f1f1;
# }
# #T_f0f59_row6_col0 {
#   background-color: #2d8fbf;
#   color: #f1f1f1;
# }
# #T_f0f59_row6_col1 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_f0f59_row7_col1 {
#   background-color: #edf8e7;
#   color: #000000;
# }
# #T_f0f59_row8_col0 {
#   background-color: #43a7cd;
#   color: #f1f1f1;
# }
# #T_f0f59_row8_col1 {
#   background-color: #80cec2;
#   color: #000000;
# }
# #T_f0f59_row9_col0 {
#   background-color: #084f91;
#   color: #f1f1f1;
# }
# #T_f0f59_row9_col1 {
#   background-color: #48accf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f0f59">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0f59_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_f0f59_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0f59_level0_row0" class="row_heading level0 row0" >Fri</th>
#       <td id="T_f0f59_row0_col0" class="data row0 col0" >1.458300</td>
#       <td id="T_f0f59_row0_col1" class="data row0 col1" >0.806981</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row1" class="row_heading level0 row1" >Sat</th>
#       <td id="T_f0f59_row1_col0" class="data row1 col0" >1.241023</td>
#       <td id="T_f0f59_row1_col1" class="data row1 col1" >2.572657</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row2" class="row_heading level0 row2" >Sun</th>
#       <td id="T_f0f59_row2_col0" class="data row2 col0" >4.695122</td>
#       <td id="T_f0f59_row2_col1" class="data row2 col1" >0.093463</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row3" class="row_heading level0 row3" >Mon</th>
#       <td id="T_f0f59_row3_col0" class="data row3 col0" >3.347891</td>
#       <td id="T_f0f59_row3_col1" class="data row3 col1" >2.901749</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row4" class="row_heading level0 row4" >Tue</th>
#       <td id="T_f0f59_row4_col0" class="data row4 col0" >3.940627</td>
#       <td id="T_f0f59_row4_col1" class="data row4 col1" >3.915681</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row5" class="row_heading level0 row5" >Wed</th>
#       <td id="T_f0f59_row5_col0" class="data row5 col0" >2.438332</td>
#       <td id="T_f0f59_row5_col1" class="data row5 col1" >3.978615</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row6" class="row_heading level0 row6" >Thu</th>
#       <td id="T_f0f59_row6_col0" class="data row6 col0" >3.964699</td>
#       <td id="T_f0f59_row6_col1" class="data row6 col1" >2.586024</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row7" class="row_heading level0 row7" >Fri</th>
#       <td id="T_f0f59_row7_col0" class="data row7 col0" >0.988728</td>
#       <td id="T_f0f59_row7_col1" class="data row7 col1" >1.226601</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row8" class="row_heading level0 row8" >Sat</th>
#       <td id="T_f0f59_row8_col0" class="data row8 col0" >3.641425</td>
#       <td id="T_f0f59_row8_col1" class="data row8 col1" >2.951747</td>
#     </tr>
#     <tr>
#       <th id="T_f0f59_level0_row9" class="row_heading level0 row9" >Sun</th>
#       <td id="T_f0f59_row9_col0" class="data row9 col0" >4.800614</td>
#       <td id="T_f0f59_row9_col1" class="data row9 col1" >3.590500</td>
#     </tr>
#   </tbody>
# </table>
