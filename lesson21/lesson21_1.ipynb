# %%
import os
key=os.environ['Gemini_API_KEY']

# %%
import google.generativeai as genai

genai.configure(api_key=key)
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("如何學習python?結果請輸出成為html格式")
print(response.text)
# Out:
# ```html
# <!DOCTYPE html>
# <html lang="zh-TW">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>如何學習 Python</title>
#     <style>
#         body {
#             font-family: sans-serif;
#             line-height: 1.6;
#         }
#         h1, h2, h3 {
#             color: #333;
#         }
#         ul {
#             list-style-type: disc;
#             margin-left: 20px;
#         }
#         a {
#             color: #007bff;
#             text-decoration: none;
#         }
#         a:hover {
#             text-decoration: underline;
#         }
#         .resource-box {
#             border: 1px solid #ccc;
#             padding: 10px;
#             margin-bottom: 10px;
#         }
#     </style>
# </head>
# <body>
#     <h1>如何學習 Python</h1>
#
#     <p>學習 Python 的過程可以循序漸進，以下提供一個學習路線圖：</p>
#
#     <h2>步驟一：選擇學習資源</h2>
#
#     <p>有很多很棒的學習資源可以幫助你開始學習 Python：</p>
#
#     <ul>
#         <li><strong>線上課程：</strong>
#             <ul>
#                 <li><a href="https://www.coursera.org/" target="_blank">Coursera</a> (提供許多 Python 課程，有些是免費的)</li>
#                 <li><a href="https://www.udemy.com/" target="_blank">Udemy</a> (許多 Python 課程，價格範圍廣泛)</li>
#                 <li><a href="https://www.codecademy.com/" target="_blank">Codecademy</a> (互動式 Python 學習平台)</li>
#                 <li><a href="https://www.freecodecamp.org/" target="_blank">freeCodeCamp</a> (提供免費的 Python 課程和專案)</li>
#             </ul>
#         </li>
#         <li><strong>書籍：</strong>  例如《Python 编程：从入门到实践》、《流畅的 Python》等。</li>
#         <li><strong>官方文件：</strong> <a href="https://docs.python.org/3/" target="_blank">Python 官方文件</a> 是非常有用的參考資源。</li>
#         <li><strong>YouTube 教程：</strong>  許多 YouTube 頻道提供 Python 程式教學影片。</li>
#     </ul>
#
#     <h2>步驟二：設定學習環境</h2>
#
#     <p>你需要安裝 Python 解釋器和一個程式碼編輯器或 IDE：</p>
#
#     <ul>
#         <li><strong>Python 解釋器：</strong> 從 <a href="https://www.python.org/" target="_blank">Python 官方網站</a> 下載並安裝。</li>
#         <li><strong>程式碼編輯器/IDE：</strong>
#             <ul>
#                 <li><strong>VS Code:</strong> 強大的免費程式碼編輯器，擁有豐富的 Python 插件。</li>
#                 <li><strong>PyCharm:</strong> 專業的 Python IDE，提供更多功能，但有付費版本。</li>
#                 <li><strong>Thonny:</strong> 適合初學者的簡潔 IDE。</li>
#             </ul>
#         </li>
#     </ul>
#
#
#     <h2>步驟三：循序漸進學習</h2>
#
#     <p>建議從基礎開始，逐步學習：</p>
#
#     <ul>
#         <li><strong>變數和資料型態</strong></li>
#         <li><strong>運算子</strong></li>
#         <li><strong>條件判斷和迴圈</strong></li>
#         <li><strong>函式</strong></li>
#         <li><strong>資料結構 (列表、字典、集合、元組)</strong></li>
#         <li><strong>物件導向程式設計 (OOP)</strong></li>
#         <li><strong>檔案處理</strong></li>
#         <li><strong>模組和套件</strong></li>
#     </ul>
#
#     <h2>步驟四：動手實踐</h2>
#
#     <p>學習程式設計最重要的是動手實踐！  嘗試完成一些小專案，例如：</p>
#     <ul>
#         <li>計算機程式</li>
#         <li>文字遊戲</li>
#         <li>簡單的網頁爬蟲</li>
#     </ul>
#
#
#     <h2>步驟五：持續學習和參與社群</h2>
#
#     <p>程式設計是一個不斷學習的過程，持續學習新的知識和技術非常重要。可以參與線上社群、討論區，與其他程式設計師交流學習。</p>
#
#
# </body>
# </html>
# ```
