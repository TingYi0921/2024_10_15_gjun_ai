# %%
import os
from dotenv import load_dotenv
load_dotenv()
key=os.environ['Gemini_API_KEY']

# %%
import google.generativeai as genai

genai.configure(api_key=key)
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("如何學習python?結果請輸出成為html格式")
print(response.text)
# Out:
# ```html
# <!DOCTYPE html>
# <html lang="zh-TW">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>如何學習 Python</title>
#     <style>
#         body {
#             font-family: sans-serif;
#             line-height: 1.6;
#         }
#         h1, h2, h3 {
#             color: #333;
#         }
#         ul {
#             list-style-type: disc;
#             margin-left: 20px;
#         }
#         a {
#             color: #007bff;
#             text-decoration: none;
#         }
#         a:hover {
#             text-decoration: underline;
#         }
#     </style>
# </head>
# <body>
#
#     <h1>如何學習 Python</h1>
#
#     <p>學習 Python 是一個循序漸進的過程，以下提供一個學習路徑，從入門到進階：</p>
#
#     <h2>一、入門階段</h2>
#
#     <h3>1. 學習基礎語法</h3>
#     <ul>
#         <li><strong>變數和資料型態：</strong> 學習如何宣告變數、不同資料型態 (整數、浮點數、字串、布林值) 的使用。</li>
#         <li><strong>運算子：</strong> 掌握算術運算子、比較運算子、邏輯運算子等。</li>
#         <li><strong>控制流程：</strong> 學習條件判斷 (if-else) 和迴圈 (for, while) 的使用。</li>
#         <li><strong>資料結構：</strong> 了解列表 (list)、元組 (tuple)、字典 (dictionary) 和集合 (set) 的特性和使用方法。</li>
#         <li><strong>函數：</strong> 學習如何定義和呼叫函數，以及函數的參數和回傳值。</li>
#     </ul>
#     <p>推薦資源：<a href="https://www.w3schools.com/python/">W3Schools Python Tutorial</a>, <a href="https://docs.python.org/3/tutorial/">Python 官方教學文件</a></p>
#
#
#     <h3>2. 練習編寫程式</h3>
#     <ul>
#         <li>從簡單的程式開始練習，例如計算器、猜數字遊戲等。</li>
#         <li>多做練習題，可以從線上平台例如 <a href="https://leetcode.com/">LeetCode</a> 或 <a href="https://www.hackerrank.com/">HackerRank</a> 上找題目。</li>
#         <li>嘗試解決實際問題，例如自動化一些日常工作。</li>
#     </ul>
#
#
#     <h2>二、進階階段</h2>
#
#     <h3>1. 學習物件導向程式設計 (OOP)</h3>
#     <ul>
#         <li>學習類別 (class)、物件 (object)、繼承 (inheritance)、多型 (polymorphism) 和封裝 (encapsulation) 等概念。</li>
#     </ul>
#
#     <h3>2. 學習常用模組和套件</h3>
#     <ul>
#         <li>例如：NumPy (數值計算)、Pandas (資料分析)、Matplotlib (資料視覺化)、Requests (網路請求)、Beautiful Soup (網頁抓取)。</li>
#     </ul>
#
#     <h3>3. 專案實作</h3>
#     <ul>
#         <li>選擇一個感興趣的專案，例如網頁爬蟲、資料分析應用程式、遊戲等，並嘗試獨立完成。</li>
#     </ul>
#
#     <h3>4. 持續學習</h3>
#     <ul>
#         <li>閱讀相關書籍和文章，關注最新的技術動態。</li>
#         <li>參與社群，與其他 Python 開發者交流學習。</li>
#     </ul>
#
#
#     <h2>三、學習資源</h2>
#
#     <ul>
#         <li><a href="https://www.python.org/">Python 官方網站</a></li>
#         <li><a href="https://www.coursera.org/">Coursera</a> (線上課程平台)</li>
#         <li><a href="https://www.udemy.com/">Udemy</a> (線上課程平台)</li>
#         <li><a href="https://realpython.com/">Real Python</a> (線上教學網站)</li>
#     </ul>
#
#
#     <p>學習 Python 需要時間和耐心，堅持下去，你一定可以學會！</p>
#
# </body>
# </html>
# ```
